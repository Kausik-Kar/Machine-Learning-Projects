# %%
import numpy as np
import pandas as pd
import seaborn as sns
#Step1: Understand your data

# %%
train = pd.read_csv('exoTrain.csv')
train.head()
# Out:
#    LABEL   FLUX.1   FLUX.2   FLUX.3   FLUX.4   FLUX.5   FLUX.6  FLUX.7  \
# 0      2    93.85    83.81    20.10   -26.98   -39.56  -124.71 -135.18
# 1      2   -38.88   -33.83   -58.54   -40.09   -79.31   -72.81  -86.55
# 2      2   532.64   535.92   513.73   496.92   456.45   466.00  464.50
# 3      2   326.52   347.39   302.35   298.13   317.74   312.70  322.33
# 4      2 -1107.21 -1112.59 -1118.95 -1095.10 -1057.55 -1034.48 -998.34
#
#     FLUX.8  FLUX.9  ...  FLUX.3188  FLUX.3189  FLUX.3190  FLUX.3191  \
# 0   -96.27  -79.89  ...     -78.07    -102.15    -102.15      25.13
# 1   -85.33  -83.97  ...      -3.28     -32.21     -32.21     -24.89
# 2   486.39  436.56  ...     -71.69      13.31      13.31     -29.89
# 3   311.31  312.42  ...       5.71      -3.73      -3.73      30.05
# 4 -1022.71 -989.57  ...    -594.37    -401.66    -401.66    -357.24
#
#    FLUX.3192  FLUX.3193  FLUX.3194  FLUX.3195  FLUX.3196  FLUX.3197
# ...

# %%
test = pd.read_csv('exoTest.csv')
test.head()
# Out:
#    LABEL   FLUX.1   FLUX.2   FLUX.3   FLUX.4   FLUX.5   FLUX.6   FLUX.7  \
# 0      2   119.88   100.21    86.46    48.68    46.12    39.39    18.57
# 1      2  5736.59  5699.98  5717.16  5692.73  5663.83  5631.16  5626.39
# 2      2   844.48   817.49   770.07   675.01   605.52   499.45   440.77
# 3      2  -826.00  -827.31  -846.12  -836.03  -745.50  -784.69  -791.22
# 4      2   -39.57   -15.88    -9.16    -6.37   -16.13   -24.05    -0.90
#
#     FLUX.8   FLUX.9  ...  FLUX.3188  FLUX.3189  FLUX.3190  FLUX.3191  \
# 0     6.98     6.63  ...      14.52      19.29      14.44      -1.62
# 1  5569.47  5550.44  ...    -581.91    -984.09   -1230.89   -1600.45
# 2   362.95   207.27  ...      17.82     -51.66     -48.29     -59.99
# 3  -746.50  -709.53  ...     122.34      93.03      93.03      68.81
# 4   -45.20    -5.04  ...     -37.87     -61.85     -27.15     -21.18
#
#    FLUX.3192  FLUX.3193  FLUX.3194  FLUX.3195  FLUX.3196  FLUX.3197
# ...

# %%
train.describe()
# Out:
#             LABEL         FLUX.1         FLUX.2         FLUX.3        FLUX.4  \
# count  466.000000     466.000000     466.000000     466.000000    466.000000
# mean     1.079399     367.591202     337.103991     312.947446    281.828734
# std      0.270651    7244.725373    6271.565319    5076.521819   4235.617137
# min      1.000000  -11442.000000  -11299.250000  -11141.000000 -10927.190000
# 25%      1.000000     -66.845000     -71.292500     -62.395000    -60.490000
# 50%      1.000000       1.910000       0.200000       3.325000      2.230000
# 75%      1.000000      71.132500      65.047500      58.262500     58.687500
# max      2.000000  150725.800000  129578.360000  102184.980000  82253.980000
#
#              FLUX.5        FLUX.6        FLUX.7        FLUX.8        FLUX.9  \
# count    466.000000    466.000000    466.000000    466.000000    466.000000
# mean     229.525687    151.380944    146.749871    139.352017    124.459828
# ...

# %%
test.describe()
# Out:
#             LABEL         FLUX.1         FLUX.2         FLUX.3         FLUX.4  \
# count  413.000000     413.000000     413.000000     413.000000     413.000000
# mean     1.012107     731.134552     738.771816     752.890073     751.924794
# std      0.109494   14347.183783   14330.838403   14319.511931   14313.434617
# min      1.000000  -15478.180000  -14663.430000  -12241.720000  -10817.590000
# 25%      1.000000     -23.300000     -26.300000     -23.060000     -21.660000
# 50%      1.000000       1.270000       0.030000      -1.070000      -1.020000
# 75%      1.000000     101.480000      91.220000      91.370000      81.190000
# max      2.000000  290882.500000  290653.500000  290554.000000  290486.500000
#
#               FLUX.5         FLUX.6         FLUX.7         FLUX.8  \
# count     413.000000     413.000000     413.000000     413.000000
# mean      755.601138     746.231477     745.689613     735.670218
# std     14301.095889   14283.390773   14241.953230   14208.120681
# ...

# %%
train.shape
# Out:
# (466, 3198)

# %%
test.shape
# Out:
# (413, 3198)

# %%
train_dataset = train.iloc[0:413, :]
train_dataset.shape
# Out:
# (413, 3198)

# %%
test_dataset = test
test_dataset.shape
# Out:
# (413, 3198)

# %%
train_dataset.head(10)
# Out:
#    LABEL   FLUX.1   FLUX.2   FLUX.3   FLUX.4   FLUX.5   FLUX.6  FLUX.7  \
# 0      2    93.85    83.81    20.10   -26.98   -39.56  -124.71 -135.18
# 1      2   -38.88   -33.83   -58.54   -40.09   -79.31   -72.81  -86.55
# 2      2   532.64   535.92   513.73   496.92   456.45   466.00  464.50
# 3      2   326.52   347.39   302.35   298.13   317.74   312.70  322.33
# 4      2 -1107.21 -1112.59 -1118.95 -1095.10 -1057.55 -1034.48 -998.34
# 5      2   211.10   163.57   179.16   187.82   188.46   168.13  203.46
# 6      2     9.34    49.96    33.30     9.63    37.64    20.85    4.54
# 7      2   238.77   262.16   277.80   190.16   180.98   123.27  103.95
# 8      2  -103.54  -118.97  -108.93   -72.25   -61.46   -50.16  -20.61
# 9      2  -265.91  -318.59  -335.66  -450.47  -453.09  -561.47 -606.03
#
#     FLUX.8  FLUX.9  ...  FLUX.3188  FLUX.3189  FLUX.3190  FLUX.3191  \
# 0   -96.27  -79.89  ...     -78.07    -102.15    -102.15      25.13
# ...

# %%
train_dataset.describe()
# Out:
#             LABEL         FLUX.1         FLUX.2         FLUX.3        FLUX.4  \
# count  413.000000     413.000000     413.000000     413.000000    413.000000
# mean     1.089588     416.706901     381.717337     354.020387    318.448765
# std      0.285938    7694.318331    6660.485105    5390.546179   4497.175488
# min      1.000000  -11442.000000  -11299.250000  -11141.000000 -10927.190000
# 25%      1.000000     -65.120000     -61.940000     -55.940000    -57.360000
# 50%      1.000000       2.200000       1.240000       4.100000      3.380000
# 75%      1.000000      71.330000      67.790000      57.940000     58.940000
# max      2.000000  150725.800000  129578.360000  102184.980000  82253.980000
#
#              FLUX.5        FLUX.6        FLUX.7        FLUX.8        FLUX.9  \
# count    413.000000    413.000000    413.000000    413.000000    413.000000
# mean     258.737748    170.011985    164.495569    155.439225    138.624770
# ...

# %%
train_dataset.columns
# Out:
# Index(['LABEL', 'FLUX.1', 'FLUX.2', 'FLUX.3', 'FLUX.4', 'FLUX.5', 'FLUX.6',
#        'FLUX.7', 'FLUX.8', 'FLUX.9',
#        ...
#        'FLUX.3188', 'FLUX.3189', 'FLUX.3190', 'FLUX.3191', 'FLUX.3192',
#        'FLUX.3193', 'FLUX.3194', 'FLUX.3195', 'FLUX.3196', 'FLUX.3197'],
#       dtype='object', length=3198)

# %%
#Find the unique values
train_dataset.nunique()
# Out:
# LABEL          2
# FLUX.1       413
# FLUX.2       413
# FLUX.3       413
# FLUX.4       412
#             ...
# FLUX.3193    413
# FLUX.3194    412
# FLUX.3195    412
# FLUX.3196    411
# FLUX.3197    412
# Length: 3198, dtype: int64

# %%
train_dataset.isnull().sum()
# Out:
# LABEL        0
# FLUX.1       0
# FLUX.2       0
# FLUX.3       0
# FLUX.4       0
#             ..
# FLUX.3193    0
# FLUX.3194    0
# FLUX.3195    0
# FLUX.3196    0
# FLUX.3197    0
# Length: 3198, dtype: int64

# %%
small_train = train_dataset.iloc[0:20, 0:5]
small_train
# Out:
#     LABEL   FLUX.1   FLUX.2   FLUX.3   FLUX.4
# 0       2    93.85    83.81    20.10   -26.98
# 1       2   -38.88   -33.83   -58.54   -40.09
# 2       2   532.64   535.92   513.73   496.92
# 3       2   326.52   347.39   302.35   298.13
# 4       2 -1107.21 -1112.59 -1118.95 -1095.10
# 5       2   211.10   163.57   179.16   187.82
# 6       2     9.34    49.96    33.30     9.63
# 7       2   238.77   262.16   277.80   190.16
# 8       2  -103.54  -118.97  -108.93   -72.25
# 9       2  -265.91  -318.59  -335.66  -450.47
# 10      2   118.81   110.97    79.53   114.25
# 11      2  -239.88  -164.28  -180.91  -225.69
# 12      2    70.34    63.86    58.37    69.43
# 13      2   424.14   407.71   461.59   428.17
# 14      2  -267.21  -239.11  -233.15  -211.84
# 15      2    35.92    45.84    47.99    74.58
# 16      2  -122.30  -122.30  -131.08  -109.69
# 17      2   -65.20   -76.33   -76.23   -72.58
# 18      2   -66.47   -15.50   -44.59   -49.03
# ...

# %%
small_test = test_dataset.iloc[0:20, 0:5]
small_test
# Out:
#     LABEL   FLUX.1   FLUX.2   FLUX.3   FLUX.4
# 0       2   119.88   100.21    86.46    48.68
# 1       2  5736.59  5699.98  5717.16  5692.73
# 2       2   844.48   817.49   770.07   675.01
# 3       2  -826.00  -827.31  -846.12  -836.03
# 4       2   -39.57   -15.88    -9.16    -6.37
# 5       1    14.28    10.63    14.56    12.42
# 6       1  -150.48  -141.72  -157.60  -184.60
# 7       1   -10.06   -12.78   -13.16    -9.81
# 8       1   454.66   440.60   382.29   361.63
# 9       1   187.40   209.60   199.91   179.62
# 10      1   205.07   177.98   163.41   159.70
# 11      1   335.74   330.21   290.66   274.18
# 12      1    -8.79     0.04     0.66    -2.63
# 13      1   449.16   419.78   357.45   355.95
# 14      1   154.58   127.27   128.86   122.53
# 15      1    -9.18    -9.43   -11.42    -8.89
# 16      1    53.85    24.78    67.64    46.14
# 17      1     3.12    -2.32     1.33    -9.67
# 18      1   -14.46    -9.69    -9.28    -7.35
# ...

# %%
#relationship analysis

# %%
small_train.shape
# Out:
# (20, 5)

# %%
corelation = small_train.corr()

# %%
sns.heatmap(corelation, xticklabels = corelation.columns, yticklabels = corelation.columns, annot = True)

# %%
sns.pairplot(small_train)

# %%
sns.relplot(x = 'FLUX.1', y = 'FLUX.2', hue = 'FLUX.4', data = small_train)

# %%
sns.distplot(small_train['FLUX.1'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.catplot(x = 'FLUX.1', kind = 'box', data = small_train)

# %%
from sklearn.datasets import load_iris
iris = load_iris()
iris.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])

# %%
df = pd.DataFrame(iris.data, columns = iris.feature_names)
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
df['Target'] = iris.target
df.tail()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      Target
# 145       2
# 146       2
# 147       2
# 148       2
# 149       2

# %%
rep = set(iris.target.tolist())
rep
# Out:
# {0, 1, 2}

# %%
rep = list(rep)
rep
# Out:
# [0, 1, 2]

# %%
names = iris.target_names.tolist()
names
# Out:
# ['setosa', 'versicolor', 'virginica']

# %%
dt = list(zip(rep,names))
dt
# Out:
# [(0, 'setosa'), (1, 'versicolor'), (2, 'virginica')]

# %%
cat_names = []

for i in df['Target']:
  cat_names.append(dt[i][1])

cat_names
# Out:
# ['setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'versicolor',
#  'versicolor',
#  'versicolor',
#  'versicolor',
#  'versicolor',
#  'versicolor',
#  'versicolor',
#  'versicolor',
#  'versicolor',
#  'versicolor',
#  'versicolor',
#  'versicolor',
#  'versicolor',
#  'versicolor',
#  'versicolor',
#  'versicolor',
#  'versicolor',
#  'versicolor',
#  'versicolor',
#  'versicolor',
# ...

# %%
df['Categorical names'] = cat_names
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    Target Categorical names
# 0       0            setosa
# 1       0            setosa
# 2       0            setosa
# 3       0            setosa
# 4       0            setosa

# %%
df.tail()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      Target Categorical names
# 145       2         virginica
# 146       2         virginica
# 147       2         virginica
# 148       2         virginica
# 149       2         virginica

# %%
df.columns
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)', 'Target', 'Categorical names'],
#       dtype='object')

# %%
sns.relplot(x = 'sepal width (cm)', y = 'petal width (cm)', hue = 'Categorical names', data = df)

# %%
sns.distplot(df['petal width (cm)'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
x = df['sepal length (cm)'].tolist()
x

# %%
y = df['petal width (cm)'].tolist()
y

# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.9.2'

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.35)

# %%
W = tf.Variable(3.0)
b = tf.Variable(2.0)

# %%
train_steps = 500
learn_rate = 0.00092

# %%
for i in range(train_steps):
  with tf.GradientTape() as tape:

    output_step = x_train*W + b

    error = output_step - y_train
    loss = tf.reduce_mean(tf.square(error))

    dW, db = tape.gradient(loss, [W,b])

    W.assign_sub(dW*learn_rate)
    b.assign_sub(db*learn_rate)

  if i%20 == 0:
    print(f"At step {i} the loss is {loss}.")
# Out:
# At step 0 the loss is 344.6830749511719.
# At step 20 the loss is 21.475170135498047.
# At step 40 the loss is 1.884550929069519.
# At step 60 the loss is 0.6965922713279724.
# At step 80 the loss is 0.62404465675354.
# At step 100 the loss is 0.6191043257713318.
# At step 120 the loss is 0.6182625889778137.
# At step 140 the loss is 0.6176699995994568.
# At step 160 the loss is 0.6170933246612549.
# At step 180 the loss is 0.6165183186531067.
# At step 200 the loss is 0.6159442067146301.
# At step 220 the loss is 0.6153708100318909.
# At step 240 the loss is 0.6147983074188232.
# At step 260 the loss is 0.6142265796661377.
# At step 280 the loss is 0.613655686378479.
# At step 300 the loss is 0.6130855083465576.
# At step 320 the loss is 0.6125161647796631.
# At step 340 the loss is 0.6119477152824402.
# At step 360 the loss is 0.6113799810409546.
# At step 380 the loss is 0.6108130812644958.
# At step 400 the loss is 0.6102468967437744.
# ...

# %%
y_pred = x_test*W + b
y_pred
# Out:
# <tf.Tensor: shape=(53,), dtype=float32, numpy=
# array([1.3974103, 1.3949871, 1.3961987, 1.3990258, 1.398218 , 1.401449 ,
#        1.4010451, 1.3957949, 1.3937755, 1.3957949, 1.3998336, 1.395391 ,
#        1.3986219, 1.3978142, 1.4018528, 1.3941793, 1.3941793, 1.398218 ,
#        1.3905445, 1.3945832, 1.3986219, 1.3885252, 1.3961987, 1.39216  ,
#        1.4006412, 1.4006412, 1.4002373, 1.3998336, 1.3970064, 1.3933716,
#        1.4002373, 1.4002373, 1.4030645, 1.4010451, 1.3978142, 1.3933716,
#        1.3986219, 1.3978142, 1.3998336, 1.3949871, 1.3929677, 1.3998336,
#        1.3974103, 1.3941793, 1.4026606, 1.398218 , 1.4002373, 1.3974103,
#        1.4006412, 1.398218 , 1.3961987, 1.3998336, 1.3929677],
#       dtype=float32)>

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize = (6,6))
plt.scatter(x_test, y_test)
plt.plot(x_test, y_pred, c = 'red')
plt.xlabel("Sepal Length (cm)")
plt.ylabel("Petal Width (cm)")
plt.show()
