# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.9.2'

# %%
mnist = tf.keras.datasets.mnist

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
x_train, x_test = x_train/255.0, x_test/255.0

# %%
import matplotlib.pyplot as plt

# %%
y_train
# Out:
# array([5, 0, 4, ..., 5, 6, 8], dtype=uint8)

# %%
plt.imshow(x_train[2])

# %%
from tensorflow.keras.models import Sequential

# %%
import tensorflow

# %%
from tensorflow.keras.layers import Flatten, Dense

# %%
model = Sequential()

# %%
model.add(Flatten(input_shape= (28,28)))

# %%
model.add(Dense(128, activation = 'relu'))
model.add(Dense(10, activation = 'softmax'))

# %%
model.compile(loss = 'sparse_categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

# %%
model.fit(x_train, y_train, epochs = 5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2554 - accuracy: 0.9277
# Epoch 2/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1132 - accuracy: 0.9664
# Epoch 3/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0775 - accuracy: 0.9766
# Epoch 4/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0580 - accuracy: 0.9821
# Epoch 5/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0446 - accuracy: 0.9865

# %%
model.evaluate(x_test, y_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0785 - accuracy: 0.9768
# [0.07854165136814117, 0.9768000245094299]

# %%
y_pred = model.predict(x_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %%
y_pred

# %%
import matplotlib.pyplot as plt
import matplotlib.image as npimg

# %%
img = npimg.imread('PakGirlTrain3.jpg')
imgplot = plt.imshow(img)
plt.show()

# %%
img1 = npimg.imread('IndianGirlTrain3.jpg')
good = plt.imshow(img1)
plt.show()

# %%
import matplotlib.pyplot as game
import matplotlib.image as picture

ext_pic = picture.imread('PakGirlTrain1.jpg')
final_pic = game.imshow(ext_pic)
game.show()

# %%
from sklearn.datasets import load_wine
wine = load_wine()
wine.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names'])

# %%
import pandas as pd

df = pd.DataFrame(wine.data, columns = wine.feature_names)
df.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline
# ...

# %%
x = df['alcohol'].values
x

# %%
y = df['hue'].values
y

# %%
import tensorflow as tf

# %%
train_steps = 100
learn_rate = 0.0000045

W = tf.Variable(4.0)
b = tf.Variable(5.0)

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.25)
x_train

# %%
y_train

# %%
for i in range(train_steps):
  with tf.GradientTape() as tape:
    output_step_vals = x_train*W + b

    error = output_step_vals - y_train
    loss = tf.reduce_mean(tf.square(error))

    dW, db = tape.gradient(loss, [W,b])

    W.assign_sub(dW*learn_rate)
    b.assign_sub(db*learn_rate)

  if i%20==0:
    print(f"At step {i} the loss is {loss}.")
# Out:
# At step 0 the loss is 2306.893310546875.
# At step 20 the loss is 2170.2802734375.
# At step 40 the loss is 2041.7584228515625.
# At step 60 the loss is 1920.8470458984375.
# At step 80 the loss is 1807.0972900390625.

# %%
y_pred = x_test*W + b
y_pred

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (6,6))
plt.scatter(x_test, y_test)
plt.plot(x_test, y_pred)
plt.show()
